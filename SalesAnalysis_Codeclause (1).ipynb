# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # The Data
# Let's start by reading in the SalesDataset.csv file into a pandas dataframe.

# %%
Sales_df= pd.read_csv('SalesDataset.csv')

# %%
Sales_df
# Out:
#        index       Date    Year     Month  Customer Age Customer Gender  \
# 0          0  2/19/2016  2016.0  February          29.0               F
# 1          1  2/20/2016  2016.0  February          29.0               F
# 2          2  2/27/2016  2016.0  February          29.0               F
# 3          3  3/12/2016  2016.0     March          29.0               F
# 4          4  3/12/2016  2016.0     March          29.0               F
# ...      ...        ...     ...       ...           ...             ...
# 34862  34862   2/7/2016  2016.0  February          38.0               M
# 34863  34863  3/13/2015  2015.0     March          38.0               M
# 34864  34864   4/5/2015  2015.0     April          38.0               M
# 34865  34865  8/30/2015  2015.0    August          38.0               M
# 34866  34866        NaN     NaN       NaN           NaN             NaN
#
#              Country           State Product Category     Sub Category  \
# 0      United States      Washington      Accessories  Tires and Tubes
# 1      United States      Washington         Clothing           Gloves
# 2      United States      Washington      Accessories  Tires and Tubes
# 3      United States      Washington      Accessories  Tires and Tubes
# 4      United States      Washington      Accessories  Tires and Tubes
# ...              ...             ...              ...              ...
# 34862         France  Hauts de Seine            Bikes   Mountain Bikes
# 34863         France  Hauts de Seine            Bikes   Mountain Bikes
# 34864         France  Hauts de Seine            Bikes   Mountain Bikes
# 34865         France  Hauts de Seine            Bikes   Mountain Bikes
# 34866            NaN             NaN              NaN              NaN
#
#        Quantity  Unit Cost   Unit Price    Cost      Revenue  Column1
# 0           1.0      80.00   109.000000    80.0   109.000000      NaN
# 1           2.0      24.50    28.500000    49.0    57.000000      NaN
# 2           3.0       3.67     5.000000    11.0    15.000000      NaN
# 3           2.0      87.50   116.500000   175.0   233.000000      NaN
# 4           3.0      35.00    41.666667   105.0   125.000000      NaN
# ...         ...        ...          ...     ...          ...      ...
# 34862       2.0    1160.00   985.500000  2320.0  1971.000000      NaN
# 34863       1.0    2049.00  1583.000000  2049.0  1583.000000      NaN
# 34864       3.0     683.00   560.666667  2049.0  1682.000000      NaN
# 34865       1.0    2320.00  1568.000000  2320.0  1568.000000      NaN
# 34866       NaN        NaN          NaN     NaN   641.532095      NaN
#
# [34867 rows x 16 columns]

# %%
# We can see that the last column and the last row have too many null values, we will deal with them later.

# %%
Sales_df.head()
# Out:
#    index       Date    Year     Month  Customer Age Customer Gender  \
# 0      0  2/19/2016  2016.0  February          29.0               F
# 1      1  2/20/2016  2016.0  February          29.0               F
# 2      2  2/27/2016  2016.0  February          29.0               F
# 3      3  3/12/2016  2016.0     March          29.0               F
# 4      4  3/12/2016  2016.0     March          29.0               F
#
#          Country       State Product Category     Sub Category  Quantity  \
# 0  United States  Washington      Accessories  Tires and Tubes       1.0
# 1  United States  Washington         Clothing           Gloves       2.0
# 2  United States  Washington      Accessories  Tires and Tubes       3.0
# 3  United States  Washington      Accessories  Tires and Tubes       2.0
# 4  United States  Washington      Accessories  Tires and Tubes       3.0
#
#    Unit Cost  Unit Price   Cost  Revenue  Column1
# 0      80.00  109.000000   80.0    109.0      NaN
# 1      24.50   28.500000   49.0     57.0      NaN
# 2       3.67    5.000000   11.0     15.0      NaN
# 3      87.50  116.500000  175.0    233.0      NaN
# 4      35.00   41.666667  105.0    125.0      NaN

# %%
Sales_df.shape
# Out:
# (34867, 16)

# %%
Sales_df.dtypes
# Out:
# index                 int64
# Date                 object
# Year                float64
# Month                object
# Customer Age        float64
# Customer Gender      object
# Country              object
# State                object
# Product Category     object
# Sub Category         object
# Quantity            float64
# Unit Cost           float64
# Unit Price          float64
# Cost                float64
# Revenue             float64
# Column1             float64
# dtype: object

# %% [markdown]
# # Exploratory Data Analysis
# Missing Data
# We can use seaborn to create a simple heatmap to see where we are missing data!

# %%
sns.heatmap(Sales_df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
# As we can see, the Column named "Column1" has a lot of null values so we will just drop the entire column from this dataset

# %%
Sales_df.drop("Column1", axis = 1, inplace = True)

# %%
# Now lets check for the row with null values

# %%
Sales_df.isna().sum()
# Out:
# index               0
# Date                1
# Year                1
# Month               1
# Customer Age        1
# Customer Gender     1
# Country             1
# State               1
# Product Category    1
# Sub Category        1
# Quantity            1
# Unit Cost           1
# Unit Price          1
# Cost                1
# Revenue             0
# dtype: int64

# %%
Sales_df[Sales_df['Date'].isna()]
# Out:
#        index Date  Year Month  Customer Age Customer Gender Country State  \
# 34866  34866  NaN   NaN   NaN           NaN             NaN     NaN   NaN
#
#       Product Category Sub Category  Quantity  Unit Cost  Unit Price  Cost  \
# 34866              NaN          NaN       NaN        NaN         NaN   NaN
#
#           Revenue
# 34866  641.532095

# %%
# This entire row has null values so we will drop this entire row

# %%
Sales_df.drop(index = 34866, inplace = True)

# %%
# Now lets see if we have any missing values

# %%
Sales_df.isna().sum()
# Out:
# index               0
# Date                0
# Year                0
# Month               0
# Customer Age        0
# Customer Gender     0
# Country             0
# State               0
# Product Category    0
# Sub Category        0
# Quantity            0
# Unit Cost           0
# Unit Price          0
# Cost                0
# Revenue             0
# dtype: int64

# %%
sns.heatmap(Sales_df.isnull(),yticklabels=False,cbar=False,cmap='viridis')
# Out:
# <Axes: >

# %%
# We have removed all the missing values from the dataset

# %% [markdown]
# # Visualization

# %%
#We added the Profit column to visualize the dataset more clearly.
Sales_df['Profit'] = Sales_df['Revenue'] - Sales_df['Cost']
Sales_df.head()
# Out:
#    index       Date    Year     Month  Customer Age Customer Gender  \
# 0      0  2/19/2016  2016.0  February          29.0               F
# 1      1  2/20/2016  2016.0  February          29.0               F
# 2      2  2/27/2016  2016.0  February          29.0               F
# 3      3  3/12/2016  2016.0     March          29.0               F
# 4      4  3/12/2016  2016.0     March          29.0               F
#
#          Country       State Product Category     Sub Category  Quantity  \
# 0  United States  Washington      Accessories  Tires and Tubes       1.0
# 1  United States  Washington         Clothing           Gloves       2.0
# 2  United States  Washington      Accessories  Tires and Tubes       3.0
# 3  United States  Washington      Accessories  Tires and Tubes       2.0
# 4  United States  Washington      Accessories  Tires and Tubes       3.0
#
#    Unit Cost  Unit Price   Cost  Revenue  Profit
# 0      80.00  109.000000   80.0    109.0    29.0
# 1      24.50   28.500000   49.0     57.0     8.0
# 2       3.67    5.000000   11.0     15.0     4.0
# 3      87.50  116.500000  175.0    233.0    58.0
# 4      35.00   41.666667  105.0    125.0    20.0

# %%
plt.figure(figsize = (4,6))

plt.pie(Sales_df["Customer Gender"].value_counts(), labels = Sales_df["Customer Gender"].value_counts().index, autopct='%1.1f%%', colors = ["cyan","fuchsia"])
plt.title("Customer Gender")

plt.show()

# %%
profit_by_gender = Sales_df.groupby(['Customer Gender','Product Category'])['Profit'].sum().reset_index().sort_values(['Customer Gender','Profit'],ascending=[True,False])
sns.barplot(data=profit_by_gender,x='Product Category',y='Profit',hue='Customer Gender')
plt.title("Product Category by gender", pad=10, fontsize=15)
plt.show()

# %%
# Now lets look at the sub-category

# %%
popular_item = Sales_df.groupby(['Sub Category', 'Customer Gender'])['Quantity'].sum().reset_index().sort_values(by = 'Quantity', ascending = False).reset_index(drop = True).head(20)
fig = plt.figure(figsize=(8,4),) 
ax = sns.barplot(data = popular_item, x = 'Quantity', y = 'Sub Category', hue = 'Customer Gender') 
plt.title("Sub Category by gender", pad=10, fontsize=15)
plt.ylabel("", labelpad=20)
plt.xlabel("", labelpad=20)
plt.axis('tight')
plt.show()

# %%
# We observe that there is not a big difference between the genders. Also the Tires and tubes are sold the most, we will analyze it later.

# %%
# Now lets look at the customer age column

# %%
for i in Sales_df["Customer Age"]:
    if i in range(15,18):
        Sales_df.loc[Sales_df["Customer Age"]== i, "Age Category"]= "15-18"
    elif i in range(19,25):
        Sales_df.loc[Sales_df["Customer Age"]== i, "Age Category"]= "19-25"
    elif i in range(25,35):
        Sales_df.loc[Sales_df["Customer Age"]== i, "Age Category"]= "25-35"
    elif i in range(35,45):
        Sales_df.loc[Sales_df["Customer Age"]== i, "Age Category"]= "35-45"
    elif i in range(45,60):
        Sales_df.loc[Sales_df["Customer Age"]== i, "Age Category"]= "45-60"
    elif i in range(60,70):
        Sales_df.loc[Sales_df["Customer Age"]== i, "Age Category"]= "60-70" 
    elif i in range(70,80):
        Sales_df.loc[Sales_df["Customer Age"]== i, "Age Category"]= "70-80"
    elif i in range(80,90):
        Sales_df.loc[Sales_df["Customer Age"]== i, "Age Category"]= "80-90"

# %%
qty_by_age= Sales_df["Quantity"].groupby(Sales_df["Age Category"]).sum()
qty_by_age.plot.bar(y="Quantity", x="Age Category", color= "blue")
plt.xlabel("Age")
plt.ylabel("Quantity")
plt.grid(True, linestyle='--', alpha=0.5)
plt.title("Quantity sold by age")
# Out:
# Text(0.5, 1.0, 'Quantity sold by age')

# %%
revenue_by_age= Sales_df["Revenue"].groupby(Sales_df["Age Category"]).sum()
revenue_by_age.plot.bar(y="Revenue", x="Age Category", color= "blue")
plt.xlabel("Age")
plt.ylabel("Revenue (in millions)")
plt.grid(True, linestyle='--', alpha=0.5)
plt.title("Revenue by age")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#We can see that most of the revenue generated as well as the Quantity sold are mostly by the customer of age between 25-35 and 35-45.

# %%
# We will create a Year_month column for further understanding the revenue
Sales_df['Date']=pd.to_datetime(Sales_df['Date'])
Sales_df['Year_Month'] = Sales_df['Date'].dt.strftime('%Y-%m')

# %%
Sales_df.head()
# Out:
#    index       Date    Year     Month  Customer Age Customer Gender  \
# 0      0 2016-02-19  2016.0  February          29.0               F
# 1      1 2016-02-20  2016.0  February          29.0               F
# 2      2 2016-02-27  2016.0  February          29.0               F
# 3      3 2016-03-12  2016.0     March          29.0               F
# 4      4 2016-03-12  2016.0     March          29.0               F
#
#          Country       State Product Category     Sub Category  Quantity  \
# 0  United States  Washington      Accessories  Tires and Tubes       1.0
# 1  United States  Washington         Clothing           Gloves       2.0
# 2  United States  Washington      Accessories  Tires and Tubes       3.0
# 3  United States  Washington      Accessories  Tires and Tubes       2.0
# 4  United States  Washington      Accessories  Tires and Tubes       3.0
#
#    Unit Cost  Unit Price   Cost  Revenue  Profit Age Category Year_Month
# 0      80.00  109.000000   80.0    109.0    29.0        25-35    2016-02
# 1      24.50   28.500000   49.0     57.0     8.0        25-35    2016-02
# 2       3.67    5.000000   11.0     15.0     4.0        25-35    2016-02
# 3      87.50  116.500000  175.0    233.0    58.0        25-35    2016-03
# 4      35.00   41.666667  105.0    125.0    20.0        25-35    2016-03

# %%
plt.figure(figsize=(10, 5))
Sales_df.groupby(['Year_Month'])['Revenue'].sum().plot(title='');

# %%
#We can see that there is sudden spike June 2015 which increased even more during December 2015, which is obvious because of Christmas.

# %%
plt.figure(figsize = (14,12))

plt.subplot(2,1,1)
sns.countplot(data = Sales_df, x = "Product Category", hue = "Country", palette = "pastel")

plt.subplot(2,1,2)
sns.countplot(data = Sales_df, x = "Sub Category", hue = "Country", palette = "pastel")
plt.xticks(rotation = 90)

plt.show()

# %%
plt.figure(figsize = (4,6))

plt.pie(Sales_df["Country"].value_counts(), labels = Sales_df["Country"].value_counts().index, autopct='%1.1f%%', colors = ["lightgreen","skyblue", "lightpink", "#CC7DFF"])
plt.title("Country Percentage")

plt.show()

# %%
#The reason why most of the products are sold in USA is becuase USA covers more than 50% of the market

# %% [markdown]
# # Conclusion :
#     1) Both the genders are equal contributors to this comapny.
#     2) This company took a huge leap in June 2015.
#     3) The target customers of this company are in the age froup of 25-35.
#     4) Tires and tubes are the most sold product.
#     5) USA covers more than 50% of the market.
